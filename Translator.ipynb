# %% [markdown]
# # Translator using Deep Learning
#
# Steps :
# 1. Importing Libraries
# 2. Importing Dataset
# 3. Data Preprocessing
# 4. Model Creation
# 5. Model Training
# 6. Model Evaluation

# %%
#Step 1 : Importing Libraries
import numpy as np
import re
import pandas as pd
import string
from unicodedata import normalize
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# %%
#Step 2 : Importing Dataset
dataset = pd.read_csv("Dataset.csv")
n_sentences = 10000
english_set = dataset.iloc[1:n_sentences, 0].values
french_set = dataset.iloc[1:n_sentences, 1].values

# %%
english_set
# Out:
# array(['Run!', 'Wow!', 'Fire!', ..., "I'm the teacher.",
#        "I'm the teacher.", "I'm tired of it."], dtype=object)

# %%
french_set
# Out:
# array(['Courez\u202f!', 'Ça alors\u202f!', 'Au feu !', ...,
#        'Je suis le professeur.', 'Je suis la professeur.',
#        "J'en ai ras le bol."], dtype=object)

# %%
# Step 3 : Data Preprocessing
clean_english_data = []
table = str.maketrans('', '', string.punctuation)
for line in english_set:
    line = normalize('NFD', line).encode('ascii', 'ignore')
    line = line.decode('UTF-8')
    line = line.split()
    # convert to lowercase
    line = [word.lower() for word in line]
    # remove punctuation
    line = [word.translate(table) for word in line]
    # remove words with numbers
    line = [word for word in line if word.isalpha()]
    line = ' '.join(line)
    clean_english_data.append(line)

# %%
clean_english_data
# Out:
# ['run',
#  'wow',
#  'fire',
#  'help',
#  'jump',
#  'stop',
#  'stop',
#  'stop',
#  'wait',
#  'wait',
#  'i see',
#  'i try',
#  'i won',
#  'i won',
#  'oh no',
#  'attack',
#  'attack',
#  'cheers',
#  'cheers',
#  'cheers',
#  'cheers',
#  'get up',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'got it',
#  'hop in',
#  'hop in',
#  'hug me',
#  'hug me',
#  'i fell',
#  'i fell',
#  'i know',
#  'i left',
#  'i left',
#  'i lost',
#  'im',
#  'im ok',
#  'im ok',
#  'listen',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'no way',
#  'really',
#  'really',
#  'really',
#  'thanks',
#  'we try',
#  'we won',
#  'we won',
#  'we won',
#  'we won',
#  'ask tom',
#  'awesome',
#  'be calm',
#  'be calm',
#  'be calm',
#  'be cool',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be fair',
#  'be kind',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'be nice',
#  'beat it',
#  'call me',
#  'call me',
#  'call us',
#  'call us',
#  'come in',
#  'come in',
#  'come in',
#  'come in',
#  'come on',
#  'come on',
#  'come on',
#  'come on',
#  'drop it',
#  'drop it',
#  'drop it',
#  'drop it',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'get out',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go away',
#  'go slow',
#  'go slow',
#  'goodbye',
#  'hang on',
#  'hang on',
#  'hang on',
#  'hang on',
#  'he quit',
#  'he quit',
#  'he runs',
#  'help me',
#  'help me',
#  'help me',
#  'help us',
#  'help us',
#  'hold it',
#  'hold on',
#  'i agree',
#  'i drive',
#  'i tried',
#  'i tried',
#  'i tried',
#  'ill go',
#  'im fat',
#  'im fat',
#  'im fit',
#  'im hit',
#  'im hit',
#  'im ill',
#  'im sad',
#  'im shy',
#  'im wet',
#  'im wet',
#  'its me',
#  'join us',
#  'join us',
#  'keep it',
#  'keep it',
#  'kiss me',
#  'kiss me',
#  'me too',
#  'open up',
#  'open up',
#  'perfect',
#  'see you',
#  'show me',
#  'show me',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'shut up',
#  'so long',
#  'take it',
#  'take it',
#  'tell me',
#  'tell me',
#  'tom won',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wake up',
#  'wash up',
#  'wash up',
#  'we know',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'we lost',
#  'who won',
#  'who won',
#  'you run',
#  'am i fat',
#  'am i fat',
#  'back off',
#  'back off',
#  'back off',
#  'back off',
#  'be a man',
#  'be a man',
#  'be still',
#  'be still',
#  'be still',
#  'beats me',
#  'beats me',
#  'call tom',
#  'call tom',
#  'cheer up',
#  'cool off',
#  'cuff him',
#  'drive on',
#  'drive on',
#  'drive on',
#  'drive on',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get down',
#  'get lost',
#  'get lost',
#  'get lost',
#  'get real',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'go ahead',
#  'good job',
#  'good job',
#  'good job',
#  'grab him',
#  'grab him',
#  'have fun',
#  'have fun',
#  'he tries',
#  'hes wet',
#  'hi guys',
#  'how cute',
#  'how deep',
#  'how nice',
#  'how nice',
#  'how nice',
#  'how nice',
#  'humor me',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'hurry up',
#  'i am fat',
#  'i did ok',
#  'i did ok',
#  'i did it',
#  'i did it',
#  'i failed',
#  'i forgot',
#  'i get it',
#  'i got it',
#  'i got it',
#  'i phoned',
#  'i phoned',
#  'i refuse',
#  'i refuse',
#  'i saw it',
#  'i saw it',
#  'i stayed',
#  'i stayed',
#  'i use it',
#  'i use it',
#  'i use it',
#  'ill pay',
#  'ill try',
#  'ill try',
#  'im back',
#  'im back',
#  'im bald',
#  'im busy',
#  'im busy',
#  'im calm',
#  'im cold',
#  'im deaf',
#  'im deaf',
#  'im done',
#  'im fast',
#  'im fine',
#  'im fine',
#  'im fine',
#  'im free',
#  'im free',
#  'im free',
#  'im full',
#  'im full',
#  'im glad',
#  'im home',
#  'im late',
#  'im lazy',
#  'im lazy',
#  'im lazy',
#  'im lazy',
#  'im okay',
#  'im okay',
#  'im safe',
#  'im sick',
#  'im sure',
#  'im sure',
#  'im sure',
#  'im sure',
#  'im tall',
#  'im thin',
#  'im tidy',
#  'im tidy',
#  'im ugly',
#  'im ugly',
#  'im weak',
#  'im well',
#  'im well',
#  'ive won',
#  'ive won',
#  'it works',
#  'it works',
#  'its his',
#  'its his',
#  'its new',
#  'its new',
#  'its odd',
#  'its sad',
#  'keep out',
#  'keep out',
#  'leave it',
#  'leave it',
#  'leave me',
#  'leave us',
#  'leave us',
#  'lets go',
#  'lets go',
#  'lets go',
#  'look out',
#  'marry me',
#  'marry me',
#  'may i go',
#  'may i go',
#  'may i go',
#  'she came',
#  'she died',
#  'she runs',
#  'sit down',
#  'sit down',
#  'sit here',
#  'sit here',
#  'speak up',
#  'speak up',
#  'stop tom',
#  'stop tom',
#  'terrific',
#  'terrific',
#  'terrific',
#  'they won',
#  'they won',
#  'they won',
#  'they won',
#  'tom came',
#  'tom died',
#  'tom left',
#  'tom left',
#  'tom lost',
#  'too late',
#  'trust me',
#  'trust me',
#  'try hard',
#  'try some',
#  'try some',
#  'try this',
#  'try this',
#  'use this',
#  'use this',
#  'use this',
#  'use this',
#  'warn tom',
#  'warn tom',
#  'watch me',
#  'watch me',
#  'watch us',
#  'watch us',
#  'we agree',
#  'well go',
#  'what for',
#  'what for',
#  'what fun',
#  'what fun',
#  'who died',
#  'whos he',
#  'write me',
#  'write me',
#  'after you',
#  'aim fire',
#  'am i late',
#  'answer me',
#  'be seated',
#  'be seated',
#  'birds fly',
#  'bless you',
#  'call home',
#  'calm down',
#  'calm down',
#  'can we go',
#  'can we go',
#  'can we go',
#  'catch him',
#  'come back',
#  'come back',
#  'come here',
#  'come here',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come over',
#  'come soon',
#  'come soon',
#  'cool down',
#  'did i win',
#  'did i win',
#  'did i win',
#  'dogs bark',
#  'dogs bark',
#  'dont ask',
#  'dont cry',
#  'dont die',
#  'dont die',
#  'dont lie',
#  'dont run',
#  'dont run',
#  'excuse me',
#  'fantastic',
#  'feel this',
#  'feel this',
#  'feel this',
#  'feel this',
#  'follow me',
#  'follow us',
#  'follow us',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'forget it',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get a job',
#  'get ready',
#  'get ready',
#  'go get it',
#  'go get it',
#  'go inside',
#  'go to bed',
#  'go to bed',
#  'good luck',
#  'good luck',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab that',
#  'grab this',
#  'grab this',
#  'hands off',
#  'he is ill',
#  'he is old',
#  'hes good',
#  'hes lazy',
#  'hes rich',
#  'here i am',
#  'heres',
#  'hold fire',
#  'hold fire',
#  'hold this',
#  'hold this',
#  'hold this',
#  'hold this',
#  'how awful',
#  'hows tom',
#  'hows tom',
#  'i am busy',
#  'i am calm',
#  'i am cold',
#  'i am fine',
#  'i am good',
#  'i am here',
#  'i am lazy',
#  'i am lazy',
#  'i am lazy',
#  'i am lazy',
#  'i am okay',
#  'i am sick',
#  'i am sure',
#  'i am sure',
#  'i am weak',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i beg you',
#  'i can run',
#  'i can ski',
#  'i cringed',
#  'i cringed',
#  'i cringed',
#  'i give up',
#  'i got hot',
#  'i got hot',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i had fun',
#  'i hate it',
#  'i hope so',
#  'i knew it',
#  'i like it',
#  'i lost it',
#  'i love it',
#  'i love it',
#  'i mean it',
#  'i mean it',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i must go',
#  'i need it',
#  'i need it',
#  'i noticed',
#  'i promise',
#  'i relaxed',
#  'i relaxed',
#  'i said no',
#  'i said so',
#  'i saw him',
#  'i saw him',
#  'i saw him',
#  'i saw one',
#  'i saw one',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i saw you',
#  'i see tom',
#  'i shouted',
#  'i tripped',
#  'i tripped',
#  'i want it',
#  'i was new',
#  'i was new',
#  'i will go',
#  'i woke up',
#  'i woke up',
#  'id agree',
#  'id leave',
#  'ill call',
#  'ill cook',
#  'ill help',
#  'ill live',
#  'ill obey',
#  'ill pack',
#  'ill pack',
#  'ill pack',
#  'ill pass',
#  'ill quit',
#  'ill sing',
#  'ill stop',
#  'ill swim',
#  'ill wait',
#  'ill walk',
#  'ill work',
#  'ill work',
#  'im a cop',
#  'im a man',
#  'im alive',
#  'im alive',
#  'im alive',
#  'im alone',
#  'im alone',
#  'im armed',
#  'im armed',
#  'im awake',
#  'im blind',
#  'im broke',
#  'im crazy',
#  'im crazy',
#  'im cured',
#  'im cured',
#  'im drunk',
#  'im drunk',
#  'im drunk',
#  'im dying',
#  'im early',
#  'im first',
#  'im fussy',
#  'im fussy',
#  'im fussy',
#  'im going',
#  'im going',
#  'im going',
#  'im going',
#  'im loyal',
#  'im loyal',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lucky',
#  'im lying',
#  'im quiet',
#  'im ready',
#  'im ready',
#  'im ready',
#  'im right',
#  'im sober',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im sorry',
#  'im stuck',
#  'im timid',
#  'im tired',
#  'im tough',
#  'im tough',
#  'im tough',
#  'im tough',
#  'im yours',
#  'im yours',
#  'ive lost',
#  'is tom ok',
#  'is tom ok',
#  'is it bad',
#  'is it far',
#  'is it far',
#  'is it you',
#  'is it you',
#  'is it you',
#  'it failed',
#  'it is new',
#  'it is new',
#  'it snowed',
#  'it stinks',
#  'it stinks',
#  'it worked',
#  'it worked',
#  'its',
#  'its cold',
#  'its cold',
#  'its dark',
#  'its dead',
#  'its dead',
#  'its dead',
#  'its done',
#  'its food',
#  'its free',
#  'its hers',
#  'its hers',
#  'its late',
#  'its lost',
#  'its open',
#  'its ours',
#  'its ours',
#  'its ours',
#  'its sand',
#  'its true',
#  'its work',
#  'let it be',
#  'let it be',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me go',
#  'let me in',
#  'let me in',
#  'lets ask',
#  'lets see',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'lie still',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'loosen up',
#  'nice shot',
#  'of course',
#  'of course',
#  'of course',
#  'of course',
#  'oh please',
#  'oh please',
#  'pardon me',
#  'pardon me',
#  'pardon me',
#  'read this',
#  'say hello',
#  'see above',
#  'seriously',
#  'seriously',
#  'seriously',
#  'she cried',
#  'she cried',
#  'she tried',
#  'she walks',
#  'shes hot',
#  'shes hot',
#  'sign here',
#  'sign here',
#  'slow down',
#  'slow down',
#  'stay back',
#  'stay back',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay calm',
#  'stay down',
#  'stay down',
#  'stay thin',
#  'stop that',
#  'stop that',
#  'stop that',
#  'take care',
#  'take care',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take mine',
#  'take this',
#  'take this',
#  'thank you',
#  'thats it',
#  'they fell',
#  'they fell',
#  'they left',
#  'they left',
#  'they lied',
#  'they lied',
#  'they lost',
#  'they lost',
#  'they swam',
#  'they swam',
#  'they swam',
#  'they swam',
#  'tom knits',
#  'tom knows',
#  'tom spoke',
#  'toms fat',
#  'try again',
#  'try again',
#  'try again',
#  'try it on',
#  'turn left',
#  'wait here',
#  'wait here',
#  'wait here',
#  'wait here',
#  'watch out',
#  'watch out',
#  'watch out',
#  'we agreed',
#  'we did it',
#  'we did it',
#  'we did it',
#  'we forgot',
#  'we saw it',
#  'we saw it',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we talked',
#  'we waited',
#  'we waited',
#  'well try',
#  'well try',
#  'well win',
#  'well win',
#  'were hot',
#  'were sad',
#  'were shy',
#  'well done',
#  'well done',
#  'well done',
#  'well done',
#  'well done',
#  'what else',
#  'what else',
#  'whats up',
#  'whats up',
#  'who cares',
#  'who cares',
#  'who cares',
#  'who is he',
#  'who is he',
#  'who is it',
#  'who is it',
#  'who knows',
#  'who spoke',
#  'wholl go',
#  'whos ill',
#  'wonderful',
#  'write tom',
#  'you drive',
#  'you drive',
#  'you drive',
#  'you idiot',
#  'you idiot',
#  'you start',
#  'you start',
#  'you tried',
#  'you tried',
#  'all aboard',
#  'am i clear',
#  'am i clear',
#  'am i dying',
#  'am i dying',
#  'am i early',
#  'am i fired',
#  'am i first',
#  'am i first',
#  'am i hired',
#  'am i hired',
#  'am i right',
#  'am i right',
#  'am i wrong',
#  'am i wrong',
#  'am i wrong',
#  'are you ok',
#  'are you up',
#  'are you up',
#  'are you up',
#  'are you up',
#  'are you up',
#  'are you up',
#  'are you up',
#  'are you up',
#  'ask anyone',
#  'ask anyone',
#  'ask anyone',
#  'ask around',
#  'ask around',
#  'be careful',
#  'be careful',
#  'be careful',
#  'be careful',
#  'be careful',
#  'be careful',
#  'be content',
#  'be content',
#  'be content',
#  'be content',
#  'be content',
#  'be content',
#  'be serious',
#  'be serious',
#  'be serious',
#  'be serious',
#  'be serious',
#  'birds sing',
#  'bottoms up',
#  'can i come',
#  'can i help',
#  'can i stay',
#  'carry this',
#  'check this',
#  'check this',
#  'choose one',
#  'choose one',
#  'come along',
#  'come on in',
#  'come on in',
#  'come quick',
#  'come quick',
#  'come to me',
#  'come to us',
#  'cut it out',
#  'cut it out',
#  'cut it out',
#  'did we win',
#  'do i stink',
#  'do come in',
#  'do men cry',
#  'dont fret',
#  'dont fret',
#  'dont fret',
#  'dont fret',
#  'dont move',
#  'dont move',
#  'dont move',
#  'dont move',
#  'dont rush',
#  'dont rush',
#  'dont talk',
#  'dont talk',
#  'dont wait',
#  'dont wait',
#  'duty calls',
#  'fill it up',
#  'find a job',
#  'find a job',
#  'follow him',
#  'follow him',
#  'forget him',
#  'forget him',
#  'forgive me',
#  'get a life',
#  'get to bed',
#  'get to bed',
#  'get to bed',
#  'give it up',
#  'give it up',
#  'go warm up',
#  'go warm up',
#  'he gave in',
#  'he gave in',
#  'he hung up',
#  'he hung up',
#  'he is busy',
#  'he is here',
#  'he is kind',
#  'he is late',
#  'he is lazy',
#  'he is lazy',
#  'he is poor',
#  'he is sick',
#  'he made it',
#  'hes swiss',
#  'hes swiss',
#  'hes broke',
#  'hes broke',
#  'hes drunk',
#  'hes drunk',
#  'hes smart',
#  'here he is',
#  'here it is',
#  'here it is',
#  'here it is',
#  'here we go',
#  'here we go',
#  'hold still',
#  'hold still',
#  'how lovely',
#  'hows work',
#  'hurry home',
#  'hurry home',
#  'i am a man',
#  'i am human',
#  'i am ready',
#  'i am right',
#  'i am sorry',
#  'i am sorry',
#  'i am tired',
#  'i am tired',
#  'i broke it',
#  'i broke it',
#  'i built it',
#  'i built it',
#  'i can come',
#  'i can cook',
#  'i can jump',
#  'i can read',
#  'i can read',
#  'i can sing',
#  'i can stay',
#  'i can swim',
#  'i can wait',
#  'i can walk',
#  'i cant go',
#  'i cant go',
#  'i cant go',
#  'i did that',
#  'i did that',
#  'i disagree',
#  'i do worry',
#  'i doubt it',
#  'i eat here',
#  'i envy him',
#  ...]

# %%
clean_french_data = []
table = str.maketrans('', '', string.punctuation)
for line in french_set:
    line = normalize('NFD', line).encode('ascii', 'ignore')
    line = line.decode('UTF-8')
    line = line.split()
    # convert to lowercase
    line = [word.lower() for word in line]
    # remove punctuation
    line = [word.translate(table) for word in line]
    # remove words with numbers
    line = [word for word in line if word.isalpha()]
    line = ' '.join(line)
    clean_french_data.append(line)

# %%
clean_french_data
# Out:
# ['courez',
#  'ca alors',
#  'au feu',
#  'a laide',
#  'saute',
#  'ca suffit',
#  'stop',
#  'arretetoi',
#  'attends',
#  'attendez',
#  'je comprends',
#  'jessaye',
#  'jai gagne',
#  'je lai emporte',
#  'oh non',
#  'attaque',
#  'attaquez',
#  'sante',
#  'a votre sante',
#  'merci',
#  'tchintchin',
#  'levetoi',
#  'jai pige',
#  'compris',
#  'pige',
#  'compris',
#  'tas capte',
#  'monte',
#  'montez',
#  'serremoi dans tes bras',
#  'serrezmoi dans vos bras',
#  'je suis tombee',
#  'je suis tombe',
#  'je sais',
#  'je suis parti',
#  'je suis partie',
#  'jai perdu',
#  'jai ans',
#  'je vais bien',
#  'ca va',
#  'ecoutez',
#  'cest pas possible',
#  'impossible',
#  'en aucun cas',
#  'cest hors de question',
#  'il nen est pas question',
#  'cest exclu',
#  'en aucune maniere',
#  'hors de question',
#  'vraiment',
#  'vrai',
#  'ah bon',
#  'merci',
#  'on essaye',
#  'nous avons gagne',
#  'nous gagnames',
#  'nous lavons emporte',
#  'nous lemportames',
#  'demande a tom',
#  'fantastique',
#  'sois calme',
#  'soyez calme',
#  'soyez calmes',
#  'sois detendu',
#  'sois juste',
#  'soyez juste',
#  'soyez justes',
#  'sois equitable',
#  'soyez equitable',
#  'soyez equitables',
#  'sois gentil',
#  'sois gentil',
#  'sois gentille',
#  'soyez gentil',
#  'soyez gentille',
#  'soyez gentils',
#  'soyez gentilles',
#  'degage',
#  'appellemoi',
#  'appellezmoi',
#  'appellenous',
#  'appeleznous',
#  'entrez',
#  'entre',
#  'entre',
#  'entrez',
#  'allez',
#  'allez',
#  'viens',
#  'venez',
#  'laisse tomber',
#  'laissez tomber',
#  'laissele tomber',
#  'laissezle tomber',
#  'sortez',
#  'sors',
#  'sortez',
#  'sors',
#  'cassetoi',
#  'degage',
#  'pars',
#  'va te faire foutre',
#  'pars',
#  'degage',
#  'fous le camp',
#  'pars dici',
#  'va ten',
#  'disparais',
#  'allezvous en',
#  'va doucement',
#  'allez doucement',
#  'a la revoyure',
#  'attends un peu',
#  'attendez un peu',
#  'tiens bon',
#  'tenez bon',
#  'il laissa tomber',
#  'il a laisse tomber',
#  'il court',
#  'aidemoi',
#  'aidemoi',
#  'aidezmoi',
#  'aideznous',
#  'aidenous',
#  'ne bouge plus',
#  'ne quittez pas',
#  'je suis du meme avis',
#  'je conduis',
#  'jessayai',
#  'jai essaye',
#  'jai tente',
#  'jirai',
#  'je suis gras',
#  'je suis gros',
#  'je suis en forme',
#  'je suis touche',
#  'je suis touchee',
#  'je suis malade',
#  'je suis triste',
#  'je suis timide',
#  'je suis mouille',
#  'je suis mouillee',
#  'cest bibi',
#  'joignezvous',
#  'joignezvous a nous',
#  'gardele',
#  'gardezle',
#  'embrassemoi',
#  'embrassezmoi',
#  'moi aussi',
#  'ouvremoi',
#  'ouvre',
#  'parfait',
#  'a plus',
#  'montremoi',
#  'montrezmoi',
#  'taisezvous',
#  'fermela',
#  'taistoi',
#  'fermela',
#  'la ferme',
#  'a plus tard',
#  'prendsle',
#  'prenezle',
#  'dismoi',
#  'ditesmoi',
#  'tom a gagne',
#  'reveilletoi',
#  'reveilletoi',
#  'reveillezvous',
#  'reveilletoi',
#  'reveillezvous',
#  'lavetoi',
#  'lavezvous',
#  'nous savons',
#  'nous perdimes',
#  'nous avons perdu',
#  'nous fumes battus',
#  'nous fumes battues',
#  'nous fumes defaits',
#  'nous fumes defaites',
#  'nous avons ete defaits',
#  'nous avons ete defaites',
#  'nous avons ete battus',
#  'nous avons ete battues',
#  'qui a gagne',
#  'qui la emporte',
#  'tu cours',
#  'suisje gros',
#  'suisje grosse',
#  'recule',
#  'reculez',
#  'retiretoi',
#  'retirezvous',
#  'sois un homme',
#  'soyez un homme',
#  'sois calme',
#  'soyez calme',
#  'soyez calmes',
#  'aucune idee',
#  'jen sais foutre rien',
#  'appelle tom',
#  'appelez tom',
#  'courage',
#  'detendstoi',
#  'menottezle',
#  'avance',
#  'avancez',
#  'continue a rouler',
#  'continuez a rouler',
#  'lachetoi',
#  'descends',
#  'descendez',
#  'lachetoi',
#  'lachezvous',
#  'va voir ailleurs si jy suis',
#  'degage',
#  'va au diable',
#  'sois realiste',
#  'vasy',
#  'poursuis',
#  'passe devant',
#  'vasy',
#  'bien joue',
#  'bon boulot',
#  'beau travail',
#  'attrapele',
#  'attrapezle',
#  'amusetoi bien',
#  'amusezvous bien',
#  'il essaye',
#  'il est mouille',
#  'salut les mecs',
#  'comme cest mignon',
#  'quelle profondeur',
#  'comme cest chouette',
#  'comme cest gentil',
#  'cest du joli',
#  'comme cest agreable',
#  'faismoi rire',
#  'depechetoi',
#  'grouille',
#  'pressezvous',
#  'fica',
#  'je suis gras',
#  'je men suis bien sorti',
#  'je men suis bien sortie',
#  'je lai fait',
#  'cest moi qui lai fait',
#  'jai echoue',
#  'jai oublie',
#  'jai compris',
#  'jai compris',
#  'jai capte',
#  'je telephonai',
#  'jai telephone',
#  'je refuse',
#  'je le refuse',
#  'je lai vu',
#  'je lai vu',
#  'je suis reste',
#  'je suis restee',
#  'je lutilise',
#  'jen fais usage',
#  'je men sers',
#  'je paierai',
#  'je vais essayer',
#  'jessaierai',
#  'je suis revenu',
#  'me revoila',
#  'je suis chauve',
#  'je suis occupe',
#  'je suis occupee',
#  'je suis calme',
#  'jai froid',
#  'je suis sourd',
#  'je suis sourde',
#  'jen ai fini',
#  'je suis rapide',
#  'tout va bien',
#  'je vais bien',
#  'ca va',
#  'je suis libre',
#  'je suis libre',
#  'je suis disponible',
#  'je suis repu',
#  'je suis rassasie',
#  'je suis content',
#  'je suis chez moi',
#  'je suis en retard',
#  'je suis paresseux',
#  'je suis faineant',
#  'je suis paresseuse',
#  'je suis faineante',
#  'je vais bien',
#  'je me porte bien',
#  'je suis en securite',
#  'je suis malade',
#  'jen suis certain',
#  'je suis certain',
#  'jen suis sur',
#  'jen suis sure',
#  'je suis grande',
#  'je suis mince',
#  'je suis ordonne',
#  'je suis ordonnee',
#  'je suis laid',
#  'je suis laide',
#  'je suis faible',
#  'je vais bien',
#  'je me porte bien',
#  'jai gagne',
#  'je lai emporte',
#  'elle marche',
#  'ca fonctionne',
#  'cest le sien',
#  'cest la sienne',
#  'cest nouveau',
#  'cest neuf',
#  'cest bizarre',
#  'cest triste',
#  'defense dentrer',
#  'nentrez pas',
#  'laisse tomber',
#  'laissez tomber',
#  'laissezmoi',
#  'laissenous',
#  'laisseznous',
#  'allonsy',
#  'allons',
#  'allonsy',
#  'attention',
#  'epousemoi',
#  'epousezmoi',
#  'puisje partir',
#  'puisje y aller',
#  'puisje my rendre',
#  'elle est venue',
#  'elle est morte',
#  'elle court',
#  'assiedstoi',
#  'asseyezvous',
#  'assiedstoi ici',
#  'asseyezvous ici',
#  'parle plus fort',
#  'parlez plus fort',
#  'arrete tom',
#  'stoppez tom',
#  'genial',
#  'excellent',
#  'formidable',
#  'ils gagnerent',
#  'elles gagnerent',
#  'ils ont gagne',
#  'elles ont gagne',
#  'tom est venu',
#  'tom est mort',
#  'tom est parti',
#  'tom partit',
#  'tom a perdu',
#  'trop tard',
#  'faitesmoi confiance',
#  'faismoi confiance',
#  'fais un effort',
#  'essaiesen',
#  'essayezen',
#  'essaie ceci',
#  'essayez ceci',
#  'utilise ceci',
#  'utilisez ceci',
#  'emploie ceci',
#  'employez ceci',
#  'avertis tom',
#  'previens tom',
#  'regardemoi',
#  'regardezmoi',
#  'regardeznous',
#  'regardenous',
#  'nous sommes daccord',
#  'nous irons',
#  'pour quoi faire',
#  'a quoi bon',
#  'questce quon sest marres',
#  'questce quon sest marrees',
#  'qui est mort',
#  'qui estil',
#  'ecrismoi',
#  'ecrivezmoi',
#  'apres vous',
#  'en joue feu',
#  'suisje en retard',
#  'repondezmoi',
#  'assiedstoi',
#  'asseyezvous',
#  'les oiseaux volent',
#  'a tes souhaits',
#  'appelle a la maison',
#  'calmezvous',
#  'calmetoi',
#  'pouvonsnous partir',
#  'pouvonsnous nous en aller',
#  'pouvonsnous y aller',
#  'rattrapele',
#  'reviens',
#  'revenez',
#  'viens ici',
#  'venez la',
#  'viens',
#  'venez',
#  'venez ici',
#  'viens chez nous',
#  'venez chez nous',
#  'viens chez moi',
#  'venez chez moi',
#  'viens bientot',
#  'venez bientot',
#  'calmezvous',
#  'aije gagne',
#  'laije emporte',
#  'estce moi qui ai gagne',
#  'des chiens aboient',
#  'les chiens aboient',
#  'ne demande pas',
#  'ne pleure pas',
#  'ne meurs pas',
#  'ne mourez pas',
#  'ne mens pas',
#  'ne courez pas',
#  'ne cours pas',
#  'excusemoi',
#  'fantastique',
#  'sens ca',
#  'sentez ca',
#  'touche ca',
#  'touchez ca',
#  'suismoi',
#  'suisnous',
#  'suiveznous',
#  'oublie',
#  'oubliele',
#  'oubliez',
#  'oubliezle',
#  'laisse tomber',
#  'oublie',
#  'trouve un emploi',
#  'trouve un boulot',
#  'trouvez un emploi',
#  'trouvez un boulot',
#  'preparetoi',
#  'preparezvous',
#  'va le chercher',
#  'allez le chercher',
#  'entrez',
#  'va au lit',
#  'allez au lit',
#  'bonne chance',
#  'bonne chance',
#  'attrape ca',
#  'attrapez ca',
#  'saisistoi de ca',
#  'saisissezvous de ca',
#  'attrape ca',
#  'attrapez ca',
#  'pas touche',
#  'il est malade',
#  'il est vieux',
#  'il est bon',
#  'il est paresseux',
#  'il est riche',
#  'me voici',
#  'voila cinq dollars',
#  'halte au feu',
#  'cessez le feu',
#  'tiens ca',
#  'tenez ca',
#  'tenez ceci',
#  'tiens ceci',
#  'cest affreux',
#  'comment tom vatil',
#  'comment va tom',
#  'je suis occupe',
#  'je suis calme',
#  'jai froid',
#  'je vais bien',
#  'je suis bon',
#  'je suis ici',
#  'je suis paresseux',
#  'je suis faineant',
#  'je suis paresseuse',
#  'je suis faineante',
#  'je vais bien',
#  'je suis malade',
#  'je suis sur',
#  'je suis certain',
#  'je suis faible',
#  'je vous en prie',
#  'je vous en conjure',
#  'je vous en supplie',
#  'je te prie',
#  'je sais courir',
#  'je sais skier',
#  'jeus un mouvement de recul',
#  'jai eu un mouvement de recul',
#  'je suis rentre en moimeme',
#  'jabandonne',
#  'je me suis mis a avoir chaud',
#  'je me suis mise a avoir chaud',
#  'je me suis amuse',
#  'je me suis amusee',
#  'je me suis marre',
#  'je me suis marree',
#  'je deteste ca',
#  'jespere bien',
#  'je le savais',
#  'jaime ca',
#  'je lai perdu',
#  'jadore ca',
#  'jadore ca',
#  'je suis serieux',
#  'je suis serieux',
#  'je dois y aller',
#  'il faut que jy aille',
#  'il me faut y aller',
#  'il me faut partir',
#  'il me faut men aller',
#  'je dois partir',
#  'je dois men aller',
#  'il faut que je men aille',
#  'jen ai besoin',
#  'il me le faut',
#  'jai remarque',
#  'je le promets',
#  'je me suis detendu',
#  'je me suis detendue',
#  'jai dit non',
#  'je lai dit',
#  'je lai vu',
#  'je lai vu',
#  'je le vis',
#  'jen ai vu une',
#  'jen ai vu un',
#  'je vous vis',
#  'je te vis',
#  'je tai vue',
#  'je tai vu',
#  'je vous ai vues',
#  'je vous ai vus',
#  'je vous ai vue',
#  'je vous ai vu',
#  'je vois tom',
#  'jai crie',
#  'jai trebuche',
#  'jai plane',
#  'je le veux',
#  'jetais nouveau',
#  'jetais nouvelle',
#  'jirai',
#  'je me suis reveille',
#  'je me suis eveille',
#  'je serais daccord',
#  'je partirais',
#  'jappellerai',
#  'je cuisinerai',
#  'jaiderai',
#  'je vivrai',
#  'jobeirai',
#  'je ferai mon sac',
#  'je ferai ma valise',
#  'je plierai mes gaules',
#  'je passerai',
#  'jabandonnerai',
#  'je chanterai',
#  'jarreterai',
#  'je nagerai',
#  'jattendrai',
#  'je marcherai',
#  'je vais travailler',
#  'je travaillerai',
#  'je suis flic',
#  'je suis un homme',
#  'je suis en vie',
#  'je suis vivant',
#  'je suis vivante',
#  'je suis seule',
#  'je suis seul',
#  'je suis arme',
#  'je suis armee',
#  'je suis reveille',
#  'je suis aveugle',
#  'je suis fauche',
#  'je suis fou',
#  'je suis folle',
#  'je suis gueri',
#  'je suis guerie',
#  'je suis saoul',
#  'je suis soul',
#  'je suis ivre',
#  'je me meurs',
#  'je suis en avance',
#  'je suis en premier',
#  'je suis difficile',
#  'je suis tatillon',
#  'je suis tatillonne',
#  'je pars maintenant',
#  'je me tire',
#  'jy vais',
#  'je pars',
#  'je suis loyal',
#  'je suis loyale',
#  'je suis veinard',
#  'je suis veinarde',
#  'jai du pot',
#  'je suis chanceux',
#  'je suis chanceuse',
#  'je suis en train de mentir',
#  'je suis tranquille',
#  'je suis prete',
#  'je suis pret',
#  'je suis pret',
#  'jai raison',
#  'je suis sobre',
#  'excusemoi',
#  'desole',
#  'desole',
#  'je suis desole',
#  'je suis desolee',
#  'je suis coincee',
#  'je suis timide',
#  'je suis fatigue',
#  'je suis dur',
#  'je suis dure',
#  'je suis dur a cuire',
#  'je suis dure a cuire',
#  'je suis a toi',
#  'je suis a vous',
#  'jai perdu',
#  'estce que tom va bien',
#  'tom vatil bien',
#  'cest grave',
#  'estce eloigne',
#  'estce loin',
#  'estce toi',
#  'estce vous',
#  'estce que cest vous',
#  'ca a echoue',
#  'cest nouveau',
#  'cest neuf',
#  'il a neige',
#  'ca sent mauvais',
#  'ca pue',
#  'ca a fonctionne',
#  'ca a marche',
#  'il est trois heures et demie',
#  'il fait froid',
#  'cest froid',
#  'cest sombre',
#  'elle est morte',
#  'cest mort',
#  'il est mort',
#  'cest fait',
#  'cest de la nourriture',
#  'cest gratuit',
#  'cest le sien',
#  'cest la sienne',
#  'il est tard',
#  'cest perdu',
#  'cest ouvert',
#  'cest le notre',
#  'cest la notre',
#  'cest a nous',
#  'cest du sable',
#  'cest vrai',
#  'cest du boulot',
#  'ainsi soitil',
#  'laisse faire',
#  'laissemoi partir',
#  'laissezmoi partir',
#  'lachemoi',
#  'laissemoi men aller',
#  'laissezmoi men aller',
#  'laissezmoi y aller',
#  'laissemoi y aller',
#  'laissemoi partir',
#  'laissezmoi partir',
#  'laissemoi men aller',
#  'laissezmoi men aller',
#  'laissezmoi rentrer',
#  'laissezmoi entrer',
#  'demandons',
#  'voyons voir',
#  'reste allonge immobile',
#  'reste allongee immobile',
#  'restez allonge immobile',
#  'restez allongee immobile',
#  'restez allonges immobiles',
#  'restez allongees immobiles',
#  'echauffetoi',
#  'echauffezvous',
#  'detendstoi',
#  'laissetoi aller',
#  'laissezvous aller',
#  'joli coup',
#  'pour sur',
#  'mais ouais',
#  'bien sur',
#  'pour sur',
#  'je vous en prie',
#  'je ten prie',
#  'pardon',
#  'je vous demande pardon',
#  'plaitil',
#  'lis ceci',
#  'dis bonjour',
#  'voyez cidessus',
#  'vraiment',
#  'estce serieux',
#  'serieusement',
#  'elle pleurait',
#  'elle pleura',
#  'elle a essaye',
#  'elle marche',
#  'elle est chaude',
#  'elle est tres attirante',
#  'signe ici',
#  'signez ici',
#  'ralentis',
#  'ralentissez',
#  'reste en arriere',
#  'restez en arriere',
#  'restez calme',
#  'reste calme',
#  'garde ton calme',
#  'garde ton sangfroid',
#  'reste tranquille',
#  'reste baisse',
#  'restez baisse',
#  'reste mince',
#  'arretez',
#  'arretez ca',
#  'arrete ca',
#  'prends soin de toi',
#  'prenez soin de vous',
#  'prends le mien',
#  'prends la mienne',
#  'prenez le mien',
#  'prenez la mienne',
#  'prends les miens',
#  'prends les miennes',
#  'prenez les miens',
#  'prenez les miennes',
#  'prends ca',
#  'prenez ca',
#  'merci',
#  'cest ca',
#  'ils sont tombes',
#  'elles sont tombees',
#  'ils sont partis',
#  'elles sont parties',
#  'ils ont menti',
#  'elles ont menti',
#  'ils ont perdu',
#  'elles ont perdu',
#  'ils nageaient',
#  'elles nageaient',
#  'ils nagerent',
#  'elles nagerent',
#  'tom tricote',
#  'tom sait',
#  'tom a parle',
#  'tom est gros',
#  'essaie encore',
#  'essayez de nouveau',
#  'essaie de nouveau',
#  'essaiele',
#  'tourne a gauche',
#  'attends ici',
#  'attends la',
#  'attendez ici',
#  'attendez la',
#  'attention',
#  'faites attention',
#  'fais attention',
#  'nous sommes tombes daccord',
#  'nous avons reussi',
#  'nous avons reussi',
#  'nous lavons fait',
#  'nous avons oublie',
#  'nous lavons vu',
#  'nous lavons vue',
#  'nous discutames',
#  'nous avons discute',
#  'nous nous sommes entretenus',
#  'nous nous sommes entretenues',
#  'nous nous entretinmes',
#  'nous attendimes',
#  'nous avons attendu',
#  'nous essayerons',
#  'nous tenterons',
#  'nous lemporterons',
#  'nous gagnerons',
#  'nous avons chaud',
#  'nous sommes tristes',
#  'nous sommes timides',
#  'bien vu',
#  'bien cuit',
#  'a la bonne heure',
#  'bien joue',
#  'pas mal',
#  'quoi dautre',
#  'quoi dautre',
#  'ca va',
#  'quoi de beau',
#  'qui sen preoccupe',
#  'qui sen soucie',
#  'a qui ceci importetil',
#  'qui estce',
#  'qui estil',
#  'qui estce',
#  'qui estil',
#  'qui sait',
#  'qui a parle',
#  'qui ira',
#  'qui est malade',
#  'magnifique',
#  'ecrivez a tom',
#  'tu conduis',
#  'toi conduis',
#  'vous conduisez',
#  'espece dimbecile',
#  'espece didiot',
#  'tu commences',
#  'vous commencez',
#  'tu as essaye',
#  'vous avez essaye',
#  'tout le monde a bord',
#  'suisje clair',
#  'suisje claire',
#  'suisje en train de mourir',
#  'suisje en train de trepasser',
#  'suisje en avance',
#  'vous me mettez a la porte',
#  'suisje le premier',
#  'suisje la premiere',
#  'suisje engage',
#  'suisje engagee',
#  'aije raison',
#  'suisje dans le vrai',
#  'me trompeje',
#  'aije tort',
#  'estce que je me trompe',
#  'estce que tu vas bien',
#  'estu leve',
#  'estu levee',
#  'etesvous leve',
#  'etesvous levee',
#  'etesvous leves',
#  'etesvous levees',
#  'estu debout',
#  'etesvous debout',
#  'demandez a nimporte qui',
#  'demande a nimporte qui',
#  'demande a quiconque',
#  'demande alentour',
#  'demandez alentour',
#  'sois prudent',
#  'sois prudente',
#  'soyez prudent',
#  'soyez prudente',
#  'soyez prudents',
#  'soyez prudentes',
#  'sois satisfait',
#  'sois satisfaite',
#  'soyez satisfait',
#  'soyez satisfaite',
#  'soyez satisfaits',
#  'soyez satisfaites',
#  'soyez serieux',
#  'soyez serieuse',
#  'soyez serieuses',
#  'sois serieux',
#  'sois serieuse',
#  'les oiseaux chantent',
#  'sante',
#  'puisje venir',
#  'puisje aider',
#  'puisje rester',
#  'portele',
#  'verifie ca',
#  'regarde ca',
#  'choisisen un',
#  'choisisen une',
#  'joignezvous a nous',
#  'entre donc',
#  'entre',
#  'viens vite',
#  'jouis vite',
#  'venez a moi',
#  'venez a nous',
#  'arrete',
#  'arretez',
#  'assez',
#  'avonsnous gagne',
#  'estce que je pue',
#  'je vous en prie entrez',
#  'les hommes pleurentils',
#  'te tracasse pas',
#  'vous tracassez pas',
#  'ne te tracasse pas',
#  'ne vous tracassez pas',
#  'ne bouge pas',
#  'ne bougez pas',
#  'ne bougez pas',
#  'ne bouge pas',
#  'ne te precipite pas',
#  'ne vous precipitez pas',
#  'ne parle pas',
#  'ne parlez pas',
#  'nattends pas',
#  'nattendez pas',
#  'le devoir mappelle',
#  'le plein',
#  'trouve un emploi',
#  'trouve un boulot',
#  'suisle',
#  'suivezle',
#  'oubliele',
#  'oubliezle',
#  'pardonnezmoi',
#  'achetetoi une vie',
#  'va au lit',
#  'au lit',
#  'allez au lit',
#  'laisse tomber',
#  'abandonne',
#  'va techauffer',
#  'allez vous echauffer',
#  'il a cede',
#  'il ceda',
#  'il a raccroche',
#  'il raccrocha',
#  'il a a faire',
#  'il est ici',
#  'il est gentil',
#  'il est en retard',
#  'il est faineant',
#  'il est paresseux',
#  'il est pauvre',
#  'il est malade',
#  'il a reussi',
#  'il est suisse',
#  'il est helvete',
#  'il est ruine',
#  'il est fauche',
#  'il est ivre',
#  'il est soul',
#  'il est intelligent',
#  'il est ici',
#  'le voila',
#  'tenez',
#  'le voici',
#  'cest parti',
#  'on est partis',
#  'tienstoi tranquille',
#  'tenezvous tranquille',
#  'comme cest charmant',
#  'comment va le travail',
#  'depechetoi daller chez toi',
#  'depechezvous daller chez vous',
#  'je suis un homme',
#  'je suis humain',
#  'je suis pret',
#  'jai raison',
#  'je suis desole',
#  'je suis desolee',
#  'je suis fatigue',
#  'je suis creve',
#  'je lai casse',
#  'je lai cassee',
#  'je lai construit',
#  'je lai construite',
#  'je peux venir',
#  'je sais cuisiner',
#  'je peux sauter',
#  'je sais lire',
#  'je peux lire',
#  'je sais chanter',
#  'je peux rester',
#  'je sais nager',
#  'je peux attendre',
#  'je peux marcher',
#  'je ne peux pas y aller',
#  'je ne peux pas my rendre',
#  'je ne peux pas partir',
#  'jai fait cela',
#  'cest moi qui lai fait',
#  'je ne suis pas daccord',
#  'je me fais vraiment du souci',
#  'jen doute',
#  'je mange ici',
#  'je lenvie',
#  ...]

# %%
# Split into test and train sets
from sklearn.model_selection import train_test_split
english_train, english_test, french_train, french_test = train_test_split(clean_english_data, clean_french_data, test_size = 0.25, random_state = 0)

# %%
# fit a tokenizer
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# max sentence length
def max_length(lines):
    return max(len(line.split()) for line in lines)

# prepare english tokenizer
eng_tokenizer = create_tokenizer(clean_english_data)
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(clean_english_data)
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare french tokenizer
fr_tokenizer = create_tokenizer(clean_french_data)
fr_vocab_size = len(fr_tokenizer.word_index) + 1
fr_length = max_length(clean_french_data)
print('French Vocabulary Size: %d' % fr_vocab_size)
print('French Max Length: %d' % (fr_length))
# Out:
# English Vocabulary Size: 2201
# English Max Length: 5
# French Vocabulary Size: 4464
# French Max Length: 10

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
    ylist = list()
    for sequence in sequences:
        encoded = to_categorical(sequence, num_classes=vocab_size)
        ylist.append(encoded)
    y = np.array(ylist)
    y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
    return y

# prepare training data
trainX = encode_sequences(fr_tokenizer, fr_length, french_train)
trainY = encode_sequences(eng_tokenizer, eng_length, english_train)
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(fr_tokenizer, fr_length, french_test)
testY = encode_sequences(eng_tokenizer, eng_length, english_test)
testY = encode_output(testY, eng_vocab_size)

# %%
# Step 4 and 5 : Model Creation and Training

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
    model = Sequential()
    model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
    model.add(LSTM(n_units))
    model.add(RepeatVector(tar_timesteps))
    model.add(LSTM(n_units, return_sequences=True))
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
    return model

# define model
model = define_model(fr_vocab_size, eng_vocab_size, fr_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY), verbose=2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 10, 256)           1142784
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 5, 256)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5, 256)            525312
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 5, 2201)           565657
# =================================================================
# Total params: 2,759,065
# Trainable params: 2,759,065
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 7499 samples, validate on 2500 samples
# Epoch 1/30
#  - 24s - loss: 4.4539 - val_loss: 3.5892
# Epoch 2/30
#  - 22s - loss: 3.3924 - val_loss: 3.3906
# Epoch 3/30
#  - 22s - loss: 3.2256 - val_loss: 3.2940
# Epoch 4/30
#  - 22s - loss: 3.0977 - val_loss: 3.2129
# Epoch 5/30
#  - 22s - loss: 2.9546 - val_loss: 3.0903
# Epoch 6/30
#  - 22s - loss: 2.8203 - val_loss: 3.0149
# Epoch 7/30
#  - 22s - loss: 2.6869 - val_loss: 2.9200
# Epoch 8/30
#  - 22s - loss: 2.5556 - val_loss: 2.8405
# Epoch 9/30
#  - 22s - loss: 2.4430 - val_loss: 2.7810
# Epoch 10/30
#  - 23s - loss: 2.3293 - val_loss: 2.7193
# Epoch 11/30
#  - 23s - loss: 2.2256 - val_loss: 2.6697
# Epoch 12/30
#  - 22s - loss: 2.1214 - val_loss: 2.6111
# Epoch 13/30
#  - 23s - loss: 2.0212 - val_loss: 2.5718
# Epoch 14/30
#  - 23s - loss: 1.9194 - val_loss: 2.5204
# Epoch 15/30
#  - 23s - loss: 1.8180 - val_loss: 2.4785
# Epoch 16/30
#  - 24s - loss: 1.7285 - val_loss: 2.4374
# Epoch 17/30
#  - 24s - loss: 1.6341 - val_loss: 2.3976
# Epoch 18/30
#  - 28s - loss: 1.5399 - val_loss: 2.3622
# Epoch 19/30
#  - 27s - loss: 1.4561 - val_loss: 2.3361
# Epoch 20/30
#  - 26s - loss: 1.3708 - val_loss: 2.3132
# Epoch 21/30
#  - 24s - loss: 1.2897 - val_loss: 2.2809
# Epoch 22/30
#  - 24s - loss: 1.2112 - val_loss: 2.2637
# Epoch 23/30
#  - 23s - loss: 1.1287 - val_loss: 2.2352
# Epoch 24/30
#  - 24s - loss: 1.0569 - val_loss: 2.2308
# Epoch 25/30
#  - 25s - loss: 0.9878 - val_loss: 2.2083
# Epoch 26/30
#  - 25s - loss: 0.9153 - val_loss: 2.1950
# Epoch 27/30
#  - 25s - loss: 0.8523 - val_loss: 2.1804
# Epoch 28/30
#  - 25s - loss: 0.7891 - val_loss: 2.1773
# Epoch 29/30
#  - 24s - loss: 0.7277 - val_loss: 2.1623
# Epoch 30/30
#  - 25s - loss: 0.6745 - val_loss: 2.1493

# %%
# Step 6 : Model Evaluation

# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [np.argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_target, raw_src):
    actual, predicted = list(), list()
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, eng_tokenizer, source)
        if i < 10:
            print('src=[%s], target=[%s], predicted=[%s]' % (raw_src[i], raw_target[i], translation))
        actual.append([raw_target[i].split()])
        predicted.append(translation.split())
    # calculate BLEU score
    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
    
    
print('train')
evaluate_model(model, eng_tokenizer, trainX, english_train, french_train)

print('test')
evaluate_model(model, eng_tokenizer, testX, english_test, french_test)
# Out:
# train
# src=[je pourrais marcher], target=[i could walk], predicted=[i could walk]
# src=[laissezvous aller], target=[loosen up], predicted=[loosen up]
# src=[cest veritable], target=[its genuine], predicted=[its lame]
# src=[faitesle de nouveau], target=[do it again], predicted=[do it again]
# src=[nous avons chaud], target=[were hot], predicted=[were starving]
# src=[les filles sont bargeots], target=[girls are crazy], predicted=[girls are crazy]
# src=[vous avez fait ca], target=[you did that], predicted=[you did that]
# src=[arretez de hurler], target=[stop yelling], predicted=[stop screaming]
# src=[je suis plutot occupee], target=[im rather busy], predicted=[im rather busy]
# src=[prenez tout], target=[take it all], predicted=[take this all]
# BLEU-1: 0.794398
# BLEU-2: 0.712552
# BLEU-3: 0.616138
# BLEU-4: 0.345425
# test
# src=[je suis presse], target=[i have to hurry], predicted=[im am in]
# src=[arrete], target=[cut it out], predicted=[stop over]
# src=[tom va arreter], target=[tomll quit], predicted=[toms is]
# src=[quel fiasco], target=[what a fiasco], predicted=[what a country]
# src=[cest a elle], target=[thats hers], predicted=[this is love]
# src=[je veux quelque chose a boire], target=[i want a drink], predicted=[i want a puppy]
# src=[cetait sympa], target=[that was nice], predicted=[that was boring]
# src=[attrapez vos affaires], target=[grab your gear], predicted=[take some]
# src=[etesvous occupees], target=[are you busy], predicted=[are you busy]
# src=[cest notre voiture], target=[its our car], predicted=[its is car]
# BLEU-1: 0.495555
# BLEU-2: 0.368949
# BLEU-3: 0.296025
# BLEU-4: 0.135239
